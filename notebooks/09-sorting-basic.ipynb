# %% [markdown]
# # Week 09 — Basic sorting**Bubble, selection, insertion — and counting sort, which does not compare.**- Plan: [`docs/course/01-study-plan.md`](../docs/course/01-study-plan.md)- Which bylaw asks for this: [`docs/course/02-coverage.md`](../docs/course/02-coverage.md)- Implement: `dsa/sorting.py`- Graded by: `tests/test_sorting.py`

# %%
# Put the repository root on sys.path so `import dsa` and `import viz` work.import sysfrom pathlib import PathROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()if str(ROOT) not in sys.path:    sys.path.insert(0, str(ROOT))print("python :", sys.version.split()[0])print("root   :", ROOT)

# %% [markdown]
# ## The contractRead the docstrings before you write anything — they state thecomplexity target, not just the behaviour.

# %%
import dsa.sortinghelp(dsa.sorting)

# %% [markdown]
# ## Try itRun this once your implementation works.

# %%
from viz.animate import step_sliderdef bubble_sort_steps(values):    values = list(values)    for i in range(len(values)):        for j in range(len(values) - i - 1):            yield values, (j, j + 1)            if values[j] > values[j + 1]:                values[j], values[j + 1] = values[j + 1], values[j]    yield values, ()step_slider(bubble_sort_steps([5, 2, 9, 1, 7]))

# %% [markdown]
# ## Your scratch spaceBreak things here. Nothing below is graded.

# %%
# ...
