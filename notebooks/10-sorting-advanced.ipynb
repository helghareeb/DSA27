# %% [markdown]
# # Week 10 — Advanced sorting**Merge, quick and heap sort — and why the pivot decides quicksort's fate.**- Plan: [`docs/course/01-study-plan.md`](../docs/course/01-study-plan.md)- Which bylaw asks for this: [`docs/course/02-coverage.md`](../docs/course/02-coverage.md)- Implement: `dsa/sorting.py`- Graded by: `tests/test_sorting.py`

# %%
# Put the repository root on sys.path so `import dsa` and `import viz` work.import sysfrom pathlib import PathROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()if str(ROOT) not in sys.path:    sys.path.insert(0, str(ROOT))print("python :", sys.version.split()[0])print("root   :", ROOT)

# %% [markdown]
# ## The contractRead the docstrings before you write anything — they state thecomplexity target, not just the behaviour.

# %%
import dsa.sortinghelp(dsa.sorting)

# %% [markdown]
# ## Try itRun this once your implementation works.

# %%
from viz.animate import animate_barsfrom IPython.display import HTML# Write merge_sort_steps as a generator and it animates for free:# HTML(animate_bars(merge_sort_steps([5, 2, 9, 1, 7, 3])).to_jshtml())

# %% [markdown]
# ## Your scratch spaceBreak things here. Nothing below is graded.

# %%
# ...
