# %% [markdown]
# # Week 13 — Hash tables**Hashing, collisions, load factor — and what breaks "O(1) average".**- Plan: [`docs/course/01-study-plan.md`](../docs/course/01-study-plan.md)- Which bylaw asks for this: [`docs/course/02-coverage.md`](../docs/course/02-coverage.md)- Implement: `dsa/hashmap.py`- Graded by: `tests/test_hashmap.py`

# %%
# Put the repository root on sys.path so `import dsa` and `import viz` work.import sysfrom pathlib import PathROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()if str(ROOT) not in sys.path:    sys.path.insert(0, str(ROOT))print("python :", sys.version.split()[0])print("root   :", ROOT)

# %% [markdown]
# ## The contractRead the docstrings before you write anything — they state thecomplexity target, not just the behaviour.

# %%
import dsa.hashmaphelp(dsa.hashmap)

# %% [markdown]
# ## Try itRun this once your implementation works.

# %%
from viz.draw import draw_array# A chaining table is an array of buckets. Draw the bucket lengths and# watch them even out as the table resizes.draw_array([2, 0, 1, 3, 0, 1, 0, 2], title="bucket occupancy")

# %% [markdown]
# ## Your scratch spaceBreak things here. Nothing below is graded.

# %%
# ...
