# %% [markdown]
# # Week 15 — The principles of language translation**Text to tokens to a tree to an answer. A stack, recursion and a tree at once.**- Plan: [`docs/course/01-study-plan.md`](../docs/course/01-study-plan.md)- Which bylaw asks for this: [`docs/course/02-coverage.md`](../docs/course/02-coverage.md)- Implement: `dsa/translation.py`- Graded by: `tests/test_translation.py`

# %%
# Put the repository root on sys.path so `import dsa` and `import viz` work.import sysfrom pathlib import PathROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()if str(ROOT) not in sys.path:    sys.path.insert(0, str(ROOT))print("python :", sys.version.split()[0])print("root   :", ROOT)

# %% [markdown]
# ## The contractRead the docstrings before you write anything — they state thecomplexity target, not just the behaviour.

# %%
import dsa.translationhelp(dsa.translation)

# %% [markdown]
# ## Try itRun this once your implementation works.

# %%
from viz.draw import draw_treefrom dsa.translation import Parser, tokenize, to_edges# ast = Parser(tokenize("3 + 4 * 2")).parse()# draw_tree(to_edges(ast))   # * sits deeper than + — that IS the precedence

# %% [markdown]
# ## Your scratch spaceBreak things here. Nothing below is graded.

# %%
# ...
