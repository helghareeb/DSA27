# %% [markdown]
# # Week 14 — Graphs and graph searches**Adjacency list vs matrix, then BFS and DFS over both.**- Plan: [`docs/course/01-study-plan.md`](../docs/course/01-study-plan.md)- Which bylaw asks for this: [`docs/course/02-coverage.md`](../docs/course/02-coverage.md)- Implement: `dsa/graph.py`- Graded by: `tests/test_graph.py`

# %%
# Put the repository root on sys.path so `import dsa` and `import viz` work.import sysfrom pathlib import PathROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()if str(ROOT) not in sys.path:    sys.path.insert(0, str(ROOT))print("python :", sys.version.split()[0])print("root   :", ROOT)

# %% [markdown]
# ## The contractRead the docstrings before you write anything — they state thecomplexity target, not just the behaviour.

# %%
import dsa.graphhelp(dsa.graph)

# %% [markdown]
# ## Try itRun this once your implementation works.

# %%
from viz.draw import draw_graphfrom dsa.graph import Graph, to_networkx# g = Graph()# for a, b in [("A","B"), ("A","C"), ("B","C"), ("B","D")]:#     g.add_edge(a, b)# draw_graph(to_networkx(g), highlight_nodes=["A"])

# %% [markdown]
# ## Your scratch spaceBreak things here. Nothing below is graded.

# %%
# ...
