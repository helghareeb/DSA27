# %% [markdown]
# # Week 04 — Arrays and dynamic arrays**Contiguous memory, O(1) indexing, and why append is *amortised* O(1).**- Plan: [`docs/course/01-study-plan.md`](../docs/course/01-study-plan.md)- Which bylaw asks for this: [`docs/course/02-coverage.md`](../docs/course/02-coverage.md)- Implement: `dsa/dynamic_array.py`- Graded by: `tests/test_dynamic_array.py`

# %%
# Put the repository root on sys.path so `import dsa` and `import viz` work.import sysfrom pathlib import PathROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()if str(ROOT) not in sys.path:    sys.path.insert(0, str(ROOT))print("python :", sys.version.split()[0])print("root   :", ROOT)

# %% [markdown]
# ## The contractRead the docstrings before you write anything — they state thecomplexity target, not just the behaviour.

# %%
import dsa.dynamic_arrayhelp(dsa.dynamic_array)

# %% [markdown]
# ## Try itRun this once your implementation works.

# %%
from viz.draw import draw_arraydraw_array([5, 2, 9, 1, 7], highlight=2, done=[0, 1])# Once DynamicArray works, plot resize_count against the number of appends# and watch the doubling show up as a staircase.

# %% [markdown]
# ## Your scratch spaceBreak things here. Nothing below is graded.

# %%
# ...
